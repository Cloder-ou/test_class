# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.6-flash",
    input="列出超級瑪莉所有的版本名稱"
)
print(interaction.output_text)
# Out:
# 「超級瑪利歐」（Super Mario，舊譯「超級瑪莉」）自 1985 年問世以來，推出了極為龐大的遊戲陣容。
#
# 為了方便您查閱，以下將瑪利歐系列劃分為**「本傳（2D/3D動作平台）」**、**「創作成員（Maker）」**以及**「主要衍生系列（賽車、派對、RPG等）」**進行完整列出：
#
# ---
#
# ### 一、 2D 正統動作系列（橫向捲軸）
#
# 1. **超級瑪利歐兄弟** (*Super Mario Bros.*) – FC/NES (1985)
# 2. **超級瑪利歐兄弟2 (日本版/Lost Levels)** (*Super Mario Bros.: The Lost Levels*) – FDS (1986)
# 3. **超級瑪利歐兄弟2 (海外版)** (*Super Mario Bros. 2*) – NES (1988)
# 4. **超級瑪利歐兄弟3** (*Super Mario Bros. 3*) – FC/NES (1988)
# 5. **超級瑪利歐世界** (*Super Mario World*) – SFC/SNES (1990)
# 6. **New 超級瑪利歐兄弟** (*New Super Mario Bros.*) – NDS (2006)
# 7. **New 超級瑪利歐兄弟 Wii** (*New Super Mario Bros. Wii*) – Wii (2009)
# 8. **New 超級瑪利歐兄弟2** (*New Super Mario Bros. 2*) – 3DS (2012)
# 9. **New 超級瑪利歐兄弟 U** (*New Super Mario Bros. U*) – Wii U (2012)
#    * *包含擴充版：《New 超級路易吉 U》*
# 10. **New 超級瑪利歐兄弟 U 豪華版** (*New Super Mario Bros. U Deluxe*) – Switch (2019)
# 11. **超級瑪利歐兄弟 驚奇** (*Super Mario Bros. Wonder*) – Switch (2023)
#
# #### 【掌機獨占 Land 系列】
# * **超級瑪利歐樂園** (*Super Mario Land*) – Game Boy (1989)
# * **超級瑪利歐樂園2 六個金幣** (*Super Mario Land 2: 6 Golden Coins*) – Game Boy (1992)
#
# ---
#
# ### 二、 3D 正統動作系列
#
# 1. **超級瑪利歐64** (*Super Mario 64*) – N64 (1996)
#    * *DS重製版：《超級瑪利歐64 DS》 (2004)*
# 2. **超級瑪利歐陽光** (*Super Mario Sunshine*) – GameCube (2002)
# 3. **超級瑪利歐銀河** (*Super Mario Galaxy*) – Wii (2007)
# 4. **超級瑪利歐銀河2** (*Super Mario Galaxy 2*) – Wii (2010)
# 5. **超級瑪利歐 3D 樂園** (*Super Mario 3D Land*) – 3DS (2011)
# 6. **超級瑪利歐 3D 世界** (*Super Mario 3D World*) – Wii U (2013)
# 7. **超級瑪利歐 奧德賽** (*Super Mario Odyssey*) – Switch (2017)
# 8. **超級瑪利歐 3D 世界 + 狂怒世界** (*Super Mario 3D World + Bowser's Fury*) – Switch (2021)
#
# ---
#
# ### 三、 瑪利歐創作家系列（自主關卡設計）
#
# 1. **超級瑪利歐創作家** (*Super Mario Maker*) – Wii U (2015)
# 2. **超級瑪利歐創作家 for 3DS** – 3DS (2016)
# 3. **超級瑪利歐創作家 2** (*Super Mario Maker 2*) – Switch (2019)
#
# ---
#
# ### 四、 主要衍生與跨界系列（代表作列舉）
#
# #### 1. 瑪利歐賽車系列 (*Mario Kart*)
# * 超級瑪利歐賽車 (SFC, 1992)
# * 瑪利歐賽車 64 (N64, 1996)
# * 瑪利歐賽車 Advance (GBA, 2001)
# * 瑪利歐賽車 雙重衝刺！！ (GC, 2003)
# * 瑪利歐賽車 DS (NDS, 2005)
# * 瑪利歐賽車 Wii (Wii, 2008)
# * 瑪利歐賽車 7 (3DS, 2011)
# * 瑪利歐賽車 8 (Wii U, 2014) / **瑪利歐賽車8 豪華版** (Switch, 2017)
# * 瑪利歐賽車 巡迴賽 (Mobile, 2019)
#
# #### 2. RPG 系列
# * **超級瑪利歐RPG** (*Super Mario RPG*) – SFC (1996) / Switch 重製版 (2023)
# * **紙片瑪利歐系列** (*Paper Mario*):
#   * 紙片瑪利歐 (N64)
#   * 紙片瑪利歐 RPG (GC / Switch重製)
#   * 超級紙片瑪利歐 (Wii)
#   * 紙片瑪利歐 貼紙之星 (3DS)
#   * 紙片瑪利歐 色彩噴濺 (Wii U)
#   * 紙片瑪利歐 折紙王 (Switch)
# * **瑪利歐與路易吉RPG系列** (*Mario & Luigi*):
#   * 瑪利歐與路易吉RPG 1~4 代 (GBA/DS/3DS)
#   * 瑪利歐與路易吉RPG 兄弟齊心！ (Switch, 2024)
#
# #### 3. 瑪利歐派對系列 (*Mario Party*)
# * 瑪利歐派對 1 代～ 10 代 (N64/GC/Wii/Wii U)
# * 超級瑪利歐派對 (*Super Mario Party*) – Switch (2018)
# * 瑪利歐派對 超級巨星 (*Mario Party Superstars*) – Switch (2021)
# * 超級瑪利歐派對 空前盛會 (*Super Mario Party Jamboree*) – Switch (2024)
#
# #### 4. 運動與運動大會系列
# * **瑪利歐網球系列** (*Mario Tennis*)
# * **瑪利歐高爾夫系列** (*Mario Golf*)
# * **瑪利歐激戰前鋒（足球）系列** (*Mario Strikers*)
# * **瑪利歐與索尼克 奧林匹克運動會系列** (Wii/3DS/Switch)
#
# #### 5. 戰術與解謎系列
# * **瑪利歐＋瘋狂兔子 系列**（王國之戰、希望之星）– Switch
# * **瑪利歐醫生系列** (*Dr. Mario*) – FC 至 Mobile
# * **瑪利歐 vs. 猩猩系列** (*Mario vs. Donkey Kong*) – GBA 至 Switch 重製版
#
# #### 6. 手機遊戲
# * **瑪利歐奔跑** (*Super Mario Run*) – iOS/Android (2016)
#
# ---
#
# ### 五、 重製與合輯版本（經典代表）
#
# * **超級瑪利歐收藏輯** (*Super Mario All-Stars*) – SFC (1993) / 含1~3代與Lost Levels重製
# * **超級瑪利歐 Advance 1~4** – GBA (2001-2003) / 2D重製版系列
# * **超級瑪利歐 3D 收藏輯** (*Super Mario 3D All-Stars*) – Switch (2020) / 收錄 64、陽光、銀河1
#
# *(註：若加上路易吉主角的《路易吉洋樓》系列、耀西主角的《耀西島》系列、瓦利歐主角的《瓦利歐工坊》系列等分支，家族遊戲總數已超過數百款。)*
