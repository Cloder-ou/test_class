# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.6-flash",
    input="列出超級瑪莉所有的版本名稱"
)
print(interaction.output_text)
# Out:
# 「超級瑪利歐」（舊譯：超級瑪莉，Super Mario）自 1985 年首作問世以來，推出了極為龐大的遊戲陣容。
#
# 以下為您整理**「超級瑪利歐」官方主線系列**以及**主要衍生系列**的完整版本名稱（以台灣／香港任天堂官方中文譯名為主）：
#
# ---
#
# ### 一、 2D 橫向捲軸主線系列（本傳）
#
# 這是最經典的吃蘑菇、跳躍踩敵人、闖關救公主模式：
#
# 1. **超級瑪利歐兄弟** (*Super Mario Bros.*) - 1985 (FC)
# 2. **超級瑪利歐兄弟 2** (*Super Mario Bros. 2 / The Lost Levels*) - 1986 (FDS，日本版高難度)
# 3. **超級瑪利歐 USA** (*Super Mario USA / Super Mario Bros. 2*) - 1988 (FC，美版2代)
# 4. **超級瑪利歐兄弟 3** (*Super Mario Bros. 3*) - 1988 (FC)
# 5. **超級瑪利歐樂園** (*Super Mario Land*) - 1989 (GB)
# 6. **超級瑪利歐世界** (*Super Mario World*) - 1990 (SFC)
# 7. **超級瑪利歐樂園2 六個金幣** (*Super Mario Land 2: 6 Golden Coins*) - 1992 (GB)
# 8. **New 超級瑪利歐兄弟** (*New Super Mario Bros.*) - 2006 (NDS)
# 9. **New 超級瑪利歐兄弟 Wii** (*New Super Mario Bros. Wii*) - 2009 (Wii)
# 10. **New 超級瑪利歐兄弟 2** (*New Super Mario Bros. 2*) - 2012 (3DS)
# 11. **New 超級瑪利歐兄弟 U** (*New Super Mario Bros. U*) - 2012 (Wii U)
#     * *New 超級路易吉 U* (2013，大型 DLC / 獨立作品)
#     * *New 超級瑪利歐兄弟 U 豪華版* (2019，Switch 移植版)
# 12. **超級瑪利歐創作家** (*Super Mario Maker*) - 2015 (Wii U/3DS)
# 13. **超級瑪利歐創作家 2** (*Super Mario Maker 2*) - 2019 (Switch)
# 14. **超級瑪利歐兄弟 驚奇** (*Super Mario Bros. Wonder*) - 2023 (Switch)
#
# ---
#
# ### 二、 3D 動作主線系列（箱庭與箱庭探索）
#
# 以自由探索、三維空間操作為主的旗艦作品：
#
# 1. **超級瑪利歐64** (*Super Mario 64*) - 1996 (N64 / 2004 NDS重製)
# 2. **超級瑪利歐陽光** (*Super Mario Sunshine*) - 2002 (NGC)
# 3. **超級瑪利歐銀河** (*Super Mario Galaxy*) - 2007 (Wii)
# 4. **超級瑪利歐銀河 2** (*Super Mario Galaxy 2*) - 2010 (Wii)
# 5. **超級瑪利歐 3D 樂園** (*Super Mario 3D Land*) - 2011 (3DS)
# 6. **超級瑪利歐 3D 世界** (*Super Mario 3D World*) - 2013 (Wii U)
#     * *超級瑪利歐 3D 世界 + 狂怒世界* (2021，Switch 強化版)
# 7. **超級瑪利歐 奧德賽** (*Super Mario Odyssey*) - 2017 (Switch)
#
# ---
#
# ### 三、 瑪利歐賽車系列（Mario Kart）
#
# 1. **超級瑪利歐賽車** (*Super Mario Kart*) - 1992 (SFC)
# 2. **瑪利歐賽車 64** - 1996 (N64)
# 3. **瑪利歐賽車 Advance** - 2001 (GBA)
# 4. **瑪利歐賽車 雙重衝刺！！** (*Double Dash!!*) - 2003 (NGC)
# 5. **瑪利歐賽車 DS** - 2005 (NDS)
# 6. **瑪利歐賽車 Wii** - 2008 (Wii)
# 7. **瑪利歐賽車 7** - 2011 (3DS)
# 8. **瑪利歐賽車 8** - 2014 (Wii U)
# 9. **瑪利歐賽車 8 豪華版** - 2017 (Switch)
# 10. **瑪利歐賽車 巡迴賽** (*Mario Kart Tour*) - 2019 (手機 iOS/Android)
# 11. **瑪利歐賽車 賽道狂飆** (*Live: Home Circuit*) - 2020 (Switch AR)
#
# ---
#
# ### 四、 RPG 與角色扮演系列
#
# #### 1. 超級瑪利歐 RPG 系列
# * **超級瑪利歐 RPG** - 1996 (SFC) / 2023 (Switch 重製版)
#
# #### 2. 紙片瑪利歐系列（Paper Mario）
# * **紙片瑪利歐** - 2000 (N64)
# * **紙片瑪利歐 RPG**（千年之門）- 2004 (NGC) / 2024 (Switch 重製版)
# * **超級紙片瑪利歐** - 2007 (Wii)
# * **紙片瑪利歐 貼紙之星** - 2012 (3DS)
# * **紙片瑪利歐 色彩噴濺** - 2016 (Wii U)
# * **紙片瑪利歐 折紙國王** - 2020 (Switch)
#
# #### 3. 瑪利歐與路易吉 RPG 系列（Mario & Luigi）
# * **瑪利歐與路易吉 RPG** - 2003 (GBA)
# * **瑪利歐與路易吉 RPG 2** - 2005 (NDS)
# * **瑪利歐與路易吉 RPG 3!!! 庫巴身體大冒險** - 2009 (NDS)
# * **瑪利歐與路易吉 RPG 4 夢境冒險** - 2013 (3DS)
# * **瑪利歐與路易吉 RPG 卡紙派對** - 2015 (3DS)
# * **瑪利歐與路易吉 RPG 兄弟齊心！** - 2024 (Switch 即將發售)
#
# #### 4. 瘋狂兔子跨界戰略系列
# * **瑪利歐 + 瘋狂兔子 戰國瘋狂** - 2017 (Switch)
# * **瑪利歐 + 瘋狂兔子 希望之星** - 2022 (Switch)
#
# ---
#
# ### 五、 瑪利歐派對系列（Mario Party）
#
# * **瑪利歐派對 1～10代** - (跨越 N64, NGC, Wii, Wii U)
# * **超級 瑪利歐派對** (*Super Mario Party*) - 2018 (Switch)
# * **瑪利歐派對 超級巨星** (*Mario Party Superstars*) - 2021 (Switch)
# * **超級 瑪利歐派對 空前盛會** (*Super Mario Party Jamboree*) - 2024 (Switch 即將發售)
#
# ---
#
# ### 六、 體育與競技系列
#
# * **瑪利歐高爾夫系列**（最新作：*瑪利歐高爾夫 超級衝刺* - 2021）
# * **瑪利歐網球系列**（最新作：*瑪利歐網球 王牌* - 2018）
# * **瑪利歐足球／激戰前鋒系列**（最新作：*瑪利歐激戰前鋒 戰鬥聯賽* - 2022）
# * **瑪利歐棒球系列**（NGC / Wii）
# * **瑪利歐與索尼克在奧林匹克運動會系列**（2008～2020 每一屆奧運合作款）
#
# ---
#
# ### 七、 手機遊戲（Mobile）
#
# 1. **超級瑪利歐 酷跑** (*Super Mario Run*) - 2016
# 2. **瑪利歐醫生世界** (*Dr. Mario World*) - 2019 (已停營)
#
# ---
#
# ### 八、 知名角色獨立/衍生系列（同瑪利歐宇宙）
#
# * **路易吉洋樓系列** (1, 2, 3 代) - 以瑪利歐弟弟「路易吉」為主角
# * **耀西系列** (如 *耀西的手工世界*) - 以恐龍「耀西」為主角
# * **瓦利歐系列** (如 *瓦利歐製造*、*瓦利歐樂園*) - 以反派「瓦利歐」為主角
# * **前進！奇諾比奧隊長** - 3D 益智解謎作品
#
# ---
#
# **總結：**
# 如果只計算**「瑪利歐橫向與3D冒險本傳」**，大約有 **20 多款**作品；若加上賽車、派對、體育、RPG 等所有冠名「超級瑪利歐」相關的遊戲，總數量已**超過 100 款以上**。
