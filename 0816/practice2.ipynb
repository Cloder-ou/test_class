# %%
print("這是我的第1個函式") #str
print('這是我的第2個函式') # str
print(50) #int
print(50.0) #float
# Out:
# 這是我的第1個函式
# 這是我的第2個函式
# 50
# 50.0

# %%
print("這是整數", 50)
print("這是浮點數", 50.5)
print("這是字串", 'robert')
print("這是布林值", True)
print("這是布林值", False)
# Out:
# 這是整數 50
# 這是浮點數 50.5
# 這是字串 robert
# 這是布林值 True
# 這是布林值 False

# %%
print(3 + 5)
print(3 + 5 + 10)
print( 3 + 5 * 2)
print((3 + 5) * 2)
print(99 ** 99)
# Out:
# 8
# 18
# 13
# 16
# 369729637649726772657187905628805440595668764281741102430259972423552570455277523421410650010128232727940978889548326540119429996769494359451621570193644014418071060667659301384999779999159200499899

# %%
a, b, c = 1, -5, 6
d = b * b - 4 * a * c
x1 = (-b + math.sqrt(d)) / (2 * a)   # 3.0
x2 = (-b - math.sqrt(d)) / (2 * a)   # 2.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 a, b, c = 1, -5, 6
#       2 d = b * b - 4 * a * c
# ----> 3 x1 = (-b + math.sqrt(d)) / (2 * a)   # 3.0
#       4 x2 = (-b - math.sqrt(d)) / (2 * a)   # 2.0
#
# NameError: name 'math' is not defined
